# %% [markdown]
# ## Импорт библиотек

# %%
import plotly
import plotly.graph_objs as go
import plotly.express as px
from plotly.subplots import make_subplots

import numpy as np
import pandas as pd

# %% [markdown]
# ## Задание 1

# %% [markdown]
# Постройте графики 2 функций:
#
# f(x) = sin(x)
#
# g(x) = 1 - cos(x)
#
# Для x на отрезке [-2𝜋; 2𝜋]

# %% [markdown]
# * Отметьте отдельными маркерами точки пересечения графиков. Оба графика должны проходить через точку пересечения при любом приближении
# * Подпишите оси и выведите заголовок
# * Выведите осевые линии
# * Подпишите графики

# %%
def f(x):
    return np.sin(x)

def g(x):
    return 1 - np.cos(x)

x = np.linspace(-2*np.pi, 2*np.pi, 100)

# %%
def x1(n):
    return np.pi/2 + 2*np.pi*n

def x2(n):
    return 2*np.pi*n

n_list = np.arange(-2, 2)
xn = np.hstack([x1(n_list), x2(n_list)])
f_g_xn = f(xn)

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=x, y=f(x), mode='lines', name='f(x)=sin(x)'))
fig.add_trace(go.Scatter(x=x, y=g(x), mode='lines', name='g(x)=1-cos(x)'))
fig.add_trace(go.Scatter(x=xn, y=f_g_xn, mode='markers', name='Точки пересечения',
                                                marker=dict(color="Green", size=7)))

fig.update_xaxes(range=[-2*np.pi, 2*np.pi], zeroline=True, zerolinewidth=1, zerolinecolor='Black')
fig.update_yaxes(zeroline=True, zerolinewidth=1, zerolinecolor='Black')

fig.update_layout(
    legend_orientation="h",
    margin=dict(l=0, r=0, t=30, b=0),
    title="График",
    xaxis_title="x",
    yaxis_title="y",
    hovermode='x'
)
fig.show()
# Out:
# <div>                            <div id="0c8aea4b-66b4-49a1-8f32-aceb66206847" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c8aea4b-66b4-49a1-8f32-aceb66206847")) {                    Plotly.newPlot(                        "0c8aea4b-66b4-49a1-8f32-aceb66206847",                        [{"mode":"lines","name":"f(x)=sin(x)","type":"scatter","x":[-6.283185307179586,-6.156252270670907,-6.029319234162229,-5.90238619765355,-5.775453161144872,-5.648520124636193,-5.521587088127515,-5.394654051618836,-5.267721015110158,-5.140787978601479,-5.013854942092801,-4.886921905584122,-4.759988869075444,-4.6330558325667655,-4.5061227960580865,-4.3791897595494085,-4.25225672304073,-4.1253236865320515,-3.998390650023373,-3.8714576135146945,-3.744524577006016,-3.617
# ...
